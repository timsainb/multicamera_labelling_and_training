# %% [markdown]
# ## This notebooks creates a Jarvis labelling set of images from a recording

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from multicamera_labelling_and_training.skeletons import sainburg25pt

# %% [markdown]
# ### Parameters

# %%
# should be a recording folder generated from multicamerae_acquisition
recording_directory = Path('/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/')

# should be a CalibrationParameters folder generated by multicamera_calibration
calibration_directory = Path('/n/groups/datta/kpts_pipeline/tim_240731/results/camera_calibration/24-05-01-13-45-07-825493/jarvis/CalibrationParameters/')

# where you want to save the labelling set
output_directory = Path("/n/groups/datta/tim_sainburg/datasets/scratch/test-labeling-sets")

# dataset name (e.g. with mouse/condition name and time)
dataset_name = '20240814-test-example-mouse' 

# choose the yaml dictionary corresponding to the dataset type you want
#   Here, I'm using the 25 point skeleton
skeleton_dict = sainburg25pt

# name of cameras
cameras = ['BackBottom', 'BackLeft', 'BackRight', 'FrontBottom', 'FrontLeft', 'FrontRight']

# %% [markdown]
# ### Ensure the contents

# %%
# !ls {calibration_directory}
# Out:
# BackBottom.yaml  BackRight.yaml    FrontLeft.yaml
# BackLeft.yaml	 FrontBottom.yaml  FrontRight.yaml

# %%
# !ls {recording_directory}
# Out:
# 24-05-01-13-26-43-110846.BackBottom.0.metadata.csv
# 24-05-01-13-26-43-110846.BackBottom.0.mp4
# 24-05-01-13-26-43-110846.BackBottom.90000.metadata.csv
# 24-05-01-13-26-43-110846.BackBottom.90000.mp4
# 24-05-01-13-26-43-110846.BackLeft.0.metadata.csv
# 24-05-01-13-26-43-110846.BackLeft.0.mp4
# 24-05-01-13-26-43-110846.BackLeft.90000.metadata.csv
# 24-05-01-13-26-43-110846.BackLeft.90000.mp4
# 24-05-01-13-26-43-110846.BackRight.0.metadata.csv
# 24-05-01-13-26-43-110846.BackRight.0.mp4
# 24-05-01-13-26-43-110846.BackRight.90000.metadata.csv
# 24-05-01-13-26-43-110846.BackRight.90000.mp4
# 24-05-01-13-26-43-110846.FrontBottom.0.metadata.csv
# 24-05-01-13-26-43-110846.FrontBottom.0.mp4
# 24-05-01-13-26-43-110846.FrontBottom.90000.metadata.csv
# 24-05-01-13-26-43-110846.FrontBottom.90000.mp4
# 24-05-01-13-26-43-110846.FrontLeft.0.metadata.csv
# 24-05-01-13-26-43-110846.FrontLeft.0.mp4
# 24-05-01-13-26-43-110846.FrontLeft.90000.metadata.csv
# 24-05-01-13-26-43-110846.FrontLeft.90000.mp4
# 24-05-01-13-26-43-110846.FrontRight.0.metadata.csv
# 24-05-01-13-26-43-110846.FrontRight.0.mp4
# 24-05-01-13-26-43-110846.FrontRight.90000.metadata.csv
# 24-05-01-13-26-43-110846.FrontRight.90000.mp4
# 24-05-01-13-26-43-110846.recording_config.yaml
# 24-05-01-13-26-43-110846.triggerdata.csv

# %% [markdown]
# ### Create and save labeling set

# %%
from multicamera_labelling_and_training.video_to_labelling_set import LabellingSetCreator

# %%
lsc = LabellingSetCreator(
    recording_directory=recording_directory,
    output_directory=output_directory,
    skeleton_dict=skeleton_dict,
    cameras = cameras,
    n_individuals=1,
    skeleton_name="RodentBody",
    n_jobs=5,
    calibration_directory=calibration_directory,
    remux_videos=True, 
)

# %%
lsc.create_labelling_set(
    dataset_name = dataset_name,
    n_frames_to_grab = 20
)
# Out:
# remuxing videos:   0%|          | 0/12 [00:00<?, ?it/s]
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x55fc5bdf7940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackBottom.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackBottom.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x55fc5be1f1c0] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=26004 q=-1.0 Lsize= 2304003kB time=00:10:00.05 bitrate=31454.3kbits/s speed= 173x
# video:2303052kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041274%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x55bf1e7b4940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackLeft.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackLeft.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x55bf1e7bafc0] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=26467 q=-1.0 Lsize= 2303791kB time=00:10:00.05 bitrate=31451.5kbits/s speed= 176x
# video:2302842kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041235%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x560827f50940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontBottom.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontBottom.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x560827f56a80] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=26689 q=-1.0 Lsize= 2303982kB time=00:10:00.05 bitrate=31454.1kbits/s speed= 178x
# video:2303032kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041254%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x5565b451f940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackRight.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackRight.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x5565b4527940] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=25934 q=-1.0 Lsize= 2303845kB time=00:10:00.05 bitrate=31452.2kbits/s speed= 173x
# video:2302895kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041258%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x5649851e0940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontRight.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontRight.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x5649851e4300] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=26373 q=-1.0 Lsize= 2303847kB time=00:10:00.05 bitrate=31452.2kbits/s speed= 176x
# video:2302898kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041247%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [h264 @ 0x55604a81d940] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontLeft.0.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontLeft.0.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x55604a98f8c0] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=90000 fps=26452 q=-1.0 Lsize= 2303872kB time=00:10:00.05 bitrate=31452.6kbits/s speed= 176x
# video:2302923kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041242%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackLeft.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackLeft.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x556a0fcb5440] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     173kB time=00:00:00.08 bitrate=16315.7kbits/s speed= 476x
# video:172kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.524918%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackBottom.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackBottom.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x5635d9879700] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     182kB time=00:00:00.08 bitrate=17206.6kbits/s speed= 484x
# video:181kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.497604%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontBottom.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontBottom.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1220x1200 [SAR 1:1 DAR 61:60], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x5594aa663b80] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     181kB time=00:00:00.08 bitrate=17090.5kbits/s speed= 419x
# video:180kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.501001%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.BackRight.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.BackRight.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x55c2031907c0] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     179kB time=00:00:00.08 bitrate=16886.2kbits/s speed= 451x
# video:178kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.507093%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontLeft.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontLeft.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x555b1f80e640] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     185kB time=00:00:00.08 bitrate=17505.0kbits/s speed= 444x
# video:184kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.489079%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/tis697/.conda/envs/jupyter_launcher --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, h264, from '/n/groups/datta/tim_sainburg/datasets/chronic24/video/M04002/24-05-01-13-26-43-110846/24-05-01-13-26-43-110846.FrontRight.90000.mp4':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], 150 fps, 150 tbr, 1200k tbn, 300 tbc
# Output #0, mp4, to '/tmp/tmp4wvey07p/24-05-01-13-26-43-110846.FrontRight.90000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1920x950 [SAR 1:1 DAR 192:95], q=2-31, 150 fps, 150 tbr, 1200k tbn, 1200k tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mp4 @ 0x55c5f5a6b5c0] Timestamps are unset in a packet for stream 0. This is deprecated and will stop working in the future. Fix your code to set the timestamps properly
# frame=    9 fps=0.0 q=-1.0 Lsize=     175kB time=00:00:00.08 bitrate=16501.4kbits/s speed= 468x
# video:174kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.518980%
# grabbing images from video:   0%|          | 0/120 [00:00<?, ?it/s]
